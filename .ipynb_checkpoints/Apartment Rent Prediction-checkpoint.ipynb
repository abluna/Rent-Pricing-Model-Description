# %%
## Bring in packages
import pandas as pd
import numpy as np
import os
import xgboost as xgb
import matplotlib.pyplot as plt
from matplotlib import pyplot
import matplotlib.ticker as ticker
import cupy

from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import root_mean_squared_error

import scipy.stats as stats
import re
import shap
import seaborn as sns

from importlib import reload

## Change some settings
pd.set_option('display.max_columns', None)

# %%
## MAC 
##os.chdir('/Users/abrahambaldenegro/Documents/GitHub/Describing-Model-Output')

## PC
os.chdir('C:/Users/abbal/OneDrive/Documents/GitHub/Rent-Pricing-Model-Description')
import ab
reload(ab)

ab.abe_says_hi()
# Out:
# fixing dummies

# %%
## Set working directory

## MAC
##os.chdir('/Users/abrahambaldenegro/Documents/House Prediction Model')

## PC
os.chdir('C:/Users/abbal/Documents/Data Science Personal Projects/Py - House Prediction')

RawData = pd.read_csv('apartments_for_rent_classified_100K.csv',
                     sep=";", encoding='cp1252', low_memory=False)

display(RawData.head(2))
# Out:
#            id                category                        title  \
# 0  5668640009  housing/rent/apartment   One BR 507 & 509 Esplanade
# 1  5668639818  housing/rent/apartment  Three BR 146 Lochview Drive
#
#                                                 body amenities  bathrooms  \
# 0  This unit is located at 507 & 509 Esplanade, R...       NaN        1.0
# 1  This unit is located at 146 Lochview Drive, Ne...       NaN        1.5
#
#    bedrooms currency fee  has_photo pets_allowed   price price_display  \
# 0       1.0      USD  No  Thumbnail         Cats  2195.0        $2,195
# 1       3.0      USD  No  Thumbnail    Cats,Dogs  1250.0        $1,250
#
#   price_type  square_feet             address       cityname state  latitude  \
# 0    Monthly          542  507  509 Esplanade  Redondo Beach    CA   33.8520
# 1    Monthly         1500     146 Lochview Dr   Newport News    VA   37.0867
#
#    longitude     source        time
# 0  -118.3759  RentLingo  1577360355
# 1   -76.4941  RentLingo  1577360340

# %%
## Let's do some cleaning
RawData = ab.clean_data(df=RawData)
# Out:
# Rows before cleaning: 99,492
# Rows after cleaning: 82,868
# Removed 16,624 rows

# %%
## Add distance to nearest city
city_locations = pd.read_csv('City Locations.csv')
RawData = ab.get_city_features(df=RawData, city_locations=city_locations)

# %%
## Set up Other Features
RawData = ab.set_up_features(df=RawData)

# %%
## Get Feature Names
all_columns = RawData.columns

feature_vars = ['bathrooms', 'bedrooms',
                'square_feet', 'body_length',
                'amenities_parking', 'amenities_gym', 'amenities_pool',
                'amenities_washer', 'photo_thumbnail', 
                'pets_dogs', 'pets_cat', 'distance_to_closest_city'] + [text for text in all_columns if re.search('^city_', text)] + [text for text in all_columns if re.search('^state_', text)]

prediction_var = "price"

# %%
## Drop Rows where any feature is missing
RawData = ab.remove_empty_rows(df=RawData, cols = feature_vars)
# Out:
# Dropping Selected Columns...
# Dropped 111 out of 82,868 rows

# %%
## Let's do some explorations
plt.hist(RawData['price'], bins = 100, color="grey")
plt.ylabel("Number of Units")
plt.xlabel("Rent Price")
plt.title("Distribution of Rent Prices")
plt.show()

# %%
## Create buckets of prices
RawData = ab.create_price_bins(df=RawData)
# Out:
# price_cat
# 01 - Very Low Price (<$1K)            19968
# 03 - Medium Price ($1.2K to $1.5K)    18490
# 04 - High Price ($1.5K to $2K)        17879
# 02 - Low Price ($1K to $1.2K)         12133
# 05 - Very High Price ($2K to ß$3K)    11181
# 06 - Highly Premium ($3K+)             3106
# Name: count, dtype: int64

# %%
display(RawData)
# Out:
#                id                category  \
# 21     5668632369  housing/rent/apartment
# 22     5668632002  housing/rent/apartment
# 23     5668631854  housing/rent/apartment
# 24     5668631790  housing/rent/apartment
# 25     5668631784  housing/rent/apartment
# ...           ...                     ...
# 99487  5121219946  housing/rent/apartment
# 99488  5121219696  housing/rent/apartment
# 99489  5121219420  housing/rent/apartment
# 99490  5121218935  housing/rent/apartment
# 99491  5121218844  housing/rent/apartment
#
#                                                    title  \
# 21                               One BR 7011 W PARMER LN
# 22                                One BR 2800 SUNRISE RD
# 23                             One BR 12330 METRIC BLVD.
# 24                              One BR 8021 FM 620 NORTH
# 25                           One BR 11500 JOLLYVILLE RD.
# ...                                                  ...
# 99487      Houston - superb Apartment nearby fine dining
# 99488  The Best of the Best in the City of Jacksonvil...
# 99489          A great & large One BR apartment. Pet OK!
# 99490  The Crest offers studio, 1, 2 & Three BR homes...
# 99491   Large Remodeled Two BR 1. Five BA Apartment Home
#
#                                                     body  \
# 21     This unit is located at 7011 W PARMER LN, Aust...
# 22     This unit is located at 2800 SUNRISE RD, Round...
# 23     This unit is located at 12330 METRIC BLVD., Au...
# 24     This unit is located at 8021 FM 620 NORTH, Aus...
# 25     This unit is located at 11500 JOLLYVILLE RD., ...
# ...                                                  ...
# 99487  Redefining urban living, in southeast Houston,...
# 99488  Courtney Manor Apartments offer the best of ev...
# 99489  Fully remodeled, new floor, kitchen cabinet, s...
# 99490  Amenities include a fitness facilities, swimmi...
# 99491  This is a brand new 2 Beds 1. five Bathrooms A...
#
#                                                amenities  bathrooms  bedrooms  \
# 21        Fireplace,Gym,Parking,Pool,Storage,Wood Floors        1.0       1.0
# 22                                            Gated,Pool        1.0       1.0
# 23                               Dishwasher,Parking,Pool        1.0       1.0
# 24                               Dishwasher,Parking,Pool        1.0       1.0
# 25                                              Gym,Pool        1.0       1.0
# ...                                                  ...        ...       ...
# 99487  Gym,Parking,Patio/Deck,Playground,Storage,Wood...        1.0       1.0
# 99488  AC,Cable or Satellite,Clubhouse,Dishwasher,Gym...        2.0       2.0
# 99489                      Garbage Disposal,Refrigerator        1.0       1.0
# 99490                                           Gym,Pool        1.0       1.0
# 99491                          Gated,Parking,Wood Floors        1.5       2.0
#
#       currency fee  has_photo pets_allowed   price price_display price_type  \
# 21         USD  No  Thumbnail          NaN  1060.0        $1,060    Monthly
# 22         USD  No  Thumbnail          NaN  1003.0        $1,003    Monthly
# 23         USD  No  Thumbnail          NaN   837.0          $837    Monthly
# 24         USD  No  Thumbnail          NaN  1020.0        $1,020    Monthly
# 25         USD  No  Thumbnail          NaN   985.0          $985    Monthly
# ...        ...  ..        ...          ...     ...           ...        ...
# 99487      USD  No        Yes          NaN   780.0          $780    Monthly
# 99488      USD  No        Yes    Cats,Dogs   813.0          $813    Monthly
# 99489      USD  No        Yes    Cats,Dogs  1325.0        $1,325    Monthly
# 99490      USD  No        Yes    Cats,Dogs   931.0          $931    Monthly
# 99491      USD  No        Yes          NaN  1595.0        $1,595    Monthly
#
#        square_feet                 address      cityname  latitude  longitude  \
# 21             650      7011 W Parmer Lane        Austin   30.3054   -97.7497
# 22             797       2800 Sunrise Road    Round Rock   30.5118   -97.6873
# 23             444  12330 Metric Boulevard        Austin   30.3054   -97.7497
# 24             692       8021 Fm 620 North        Austin   30.3054   -97.7497
# 25             693   11500 Jollyville Road        Austin   30.3054   -97.7497
# ...            ...                     ...           ...       ...        ...
# 99487          605                     NaN       Houston   29.6151   -95.1998
# 99488          921                     NaN  Jacksonville   30.2254   -81.7579
# 99489          650                     NaN     San Diego   32.7379  -117.0914
# 99490          701                     NaN  Huntersville   35.4158   -80.8451
# 99491          900                     NaN     San Diego   32.7379  -117.0914
#
#              source        time  distance_to_closest_city  orig_closest_city  \
# 21        RentLingo  1577359827                  0.004610        city_austin
# 22        RentLingo  1577359796                  0.211316        city_austin
# 23        RentLingo  1577359784                  0.004610        city_austin
# 24        RentLingo  1577359778                  0.004610        city_austin
# 25        RentLingo  1577359777                  0.004610        city_austin
# ...             ...         ...                       ...                ...
# 99487  RentDigs.com  1544185770                  0.292174       city_houston
# 99488  RentDigs.com  1544185750                  0.143267  city_jacksonville
# 99489  RentDigs.com  1544185729                  0.086950     city_san_diego
# 99490  RentDigs.com  1544185670                  0.216328     city_charlotte
# 99491  RentDigs.com  1544185659                  0.086950     city_san_diego
#
#        city_albuquerque  city_anaheim  city_anchorage  city_arlington  \
# 21                    0             0               0               0
# 22                    0             0               0               0
# 23                    0             0               0               0
# 24                    0             0               0               0
# 25                    0             0               0               0
# ...                 ...           ...             ...             ...
# 99487                 0             0               0               0
# 99488                 0             0               0               0
# 99489                 0             0               0               0
# 99490                 0             0               0               0
# 99491                 0             0               0               0
#
#        city_atlanta  city_aurora  city_austin  city_bakersfield  \
# 21                0            0            1                 0
# 22                0            0            1                 0
# 23                0            0            1                 0
# 24                0            0            1                 0
# 25                0            0            1                 0
# ...             ...          ...          ...               ...
# 99487             0            0            0                 0
# 99488             0            0            0                 0
# 99489             0            0            0                 0
# 99490             0            0            0                 0
# 99491             0            0            0                 0
#
#        city_baltimore  city_boise  city_boston  city_buffalo  city_chandler  \
# 21                  0           0            0             0              0
# 22                  0           0            0             0              0
# 23                  0           0            0             0              0
# 24                  0           0            0             0              0
# 25                  0           0            0             0              0
# ...               ...         ...          ...           ...            ...
# 99487               0           0            0             0              0
# 99488               0           0            0             0              0
# 99489               0           0            0             0              0
# 99490               0           0            0             0              0
# 99491               0           0            0             0              0
#
#        city_charlotte  city_chesapeake  city_chicago  city_chula_vista  \
# 21                  0                0             0                 0
# 22                  0                0             0                 0
# 23                  0                0             0                 0
# 24                  0                0             0                 0
# 25                  0                0             0                 0
# ...               ...              ...           ...               ...
# 99487               0                0             0                 0
# 99488               0                0             0                 0
# 99489               0                0             0                 0
# 99490               1                0             0                 0
# 99491               0                0             0                 0
#
#        city_cincinnati  city_cleveland  city_colorado_springs  city_columbus  \
# 21                   0               0                      0              0
# 22                   0               0                      0              0
# 23                   0               0                      0              0
# 24                   0               0                      0              0
# 25                   0               0                      0              0
# ...                ...             ...                    ...            ...
# 99487                0               0                      0              0
# 99488                0               0                      0              0
# 99489                0               0                      0              0
# 99490                0               0                      0              0
# 99491                0               0                      0              0
#
#        city_corpus_christi  city_dallas  city_denver  city_detroit  \
# 21                       0            0            0             0
# 22                       0            0            0             0
# 23                       0            0            0             0
# 24                       0            0            0             0
# 25                       0            0            0             0
# ...                    ...          ...          ...           ...
# 99487                    0            0            0             0
# 99488                    0            0            0             0
# 99489                    0            0            0             0
# 99490                    0            0            0             0
# 99491                    0            0            0             0
#
#        city_durham  city_el_paso  city_enterprise  city_fort_wayne  \
# 21               0             0                0                0
# 22               0             0                0                0
# 23               0             0                0                0
# 24               0             0                0                0
# 25               0             0                0                0
# ...            ...           ...              ...              ...
# 99487            0             0                0                0
# 99488            0             0                0                0
# 99489            0             0                0                0
# 99490            0             0                0                0
# 99491            0             0                0                0
#
#        city_fort_worth  city_fremont  city_fresno  city_garland  city_gilbert  \
# 21                   0             0            0             0             0
# 22                   0             0            0             0             0
# 23                   0             0            0             0             0
# 24                   0             0            0             0             0
# 25                   0             0            0             0             0
# ...                ...           ...          ...           ...           ...
# 99487                0             0            0             0             0
# 99488                0             0            0             0             0
# 99489                0             0            0             0             0
# 99490                0             0            0             0             0
# 99491                0             0            0             0             0
#
#        city_glendale  city_greensboro  city_henderson  city_honolulu  \
# 21                 0                0               0              0
# 22                 0                0               0              0
# 23                 0                0               0              0
# 24                 0                0               0              0
# 25                 0                0               0              0
# ...              ...              ...             ...            ...
# 99487              0                0               0              0
# 99488              0                0               0              0
# 99489              0                0               0              0
# 99490              0                0               0              0
# 99491              0                0               0              0
#
#        city_houston  city_indianapolis  city_irvine  city_jacksonville  \
# 21                0                  0            0                  0
# 22                0                  0            0                  0
# 23                0                  0            0                  0
# 24                0                  0            0                  0
# 25                0                  0            0                  0
# ...             ...                ...          ...                ...
# 99487             1                  0            0                  0
# 99488             0                  0            0                  1
# 99489             0                  0            0                  0
# 99490             0                  0            0                  0
# 99491             0                  0            0                  0
#
#        city_jersey_city  city_kansas_city  city_laredo  city_las_vegas  \
# 21                    0                 0            0               0
# 22                    0                 0            0               0
# 23                    0                 0            0               0
# 24                    0                 0            0               0
# 25                    0                 0            0               0
# ...                 ...               ...          ...             ...
# 99487                 0                 0            0               0
# 99488                 0                 0            0               0
# 99489                 0                 0            0               0
# 99490                 0                 0            0               0
# 99491                 0                 0            0               0
#
#        city_lexington  city_lincoln  city_long_beach  city_los_angeles  \
# 21                  0             0                0                 0
# 22                  0             0                0                 0
# 23                  0             0                0                 0
# 24                  0             0                0                 0
# 25                  0             0                0                 0
# ...               ...           ...              ...               ...
# 99487               0             0                0                 0
# 99488               0             0                0                 0
# 99489               0             0                0                 0
# 99490               0             0                0                 0
# 99491               0             0                0                 0
#
#        city_louisville  city_lubbock  city_madison  city_memphis  city_mesa  \
# 21                   0             0             0             0          0
# 22                   0             0             0             0          0
# 23                   0             0             0             0          0
# 24                   0             0             0             0          0
# 25                   0             0             0             0          0
# ...                ...           ...           ...           ...        ...
# 99487                0             0             0             0          0
# 99488                0             0             0             0          0
# 99489                0             0             0             0          0
# 99490                0             0             0             0          0
# 99491                0             0             0             0          0
#
#        city_miami  city_milwaukee  city_minneapolis  city_nashville  \
# 21              0               0                 0               0
# 22              0               0                 0               0
# 23              0               0                 0               0
# 24              0               0                 0               0
# 25              0               0                 0               0
# ...           ...             ...               ...             ...
# 99487           0               0                 0               0
# 99488           0               0                 0               0
# 99489           0               0                 0               0
# 99490           0               0                 0               0
# 99491           0               0                 0               0
#
#        city_new_orleans  city_new_york_city  city_newark  city_norfolk  \
# 21                    0                   0            0             0
# 22                    0                   0            0             0
# 23                    0                   0            0             0
# 24                    0                   0            0             0
# 25                    0                   0            0             0
# ...                 ...                 ...          ...           ...
# 99487                 0                   0            0             0
# 99488                 0                   0            0             0
# 99489                 0                   0            0             0
# 99490                 0                   0            0             0
# 99491                 0                   0            0             0
#
#        city_north_las_vegas  city_oakland  city_oklahoma_city  city_omaha  \
# 21                        0             0                   0           0
# 22                        0             0                   0           0
# 23                        0             0                   0           0
# 24                        0             0                   0           0
# 25                        0             0                   0           0
# ...                     ...           ...                 ...         ...
# 99487                     0             0                   0           0
# 99488                     0             0                   0           0
# 99489                     0             0                   0           0
# 99490                     0             0                   0           0
# 99491                     0             0                   0           0
#
#        city_orlando  city_philadelphia  city_phoenix  city_pittsburgh  \
# 21                0                  0             0                0
# 22                0                  0             0                0
# 23                0                  0             0                0
# 24                0                  0             0                0
# 25                0                  0             0                0
# ...             ...                ...           ...              ...
# 99487             0                  0             0                0
# 99488             0                  0             0                0
# 99489             0                  0             0                0
# 99490             0                  0             0                0
# 99491             0                  0             0                0
#
#        city_plano  city_portland  city_raleigh  city_reno  city_riverside  \
# 21              0              0             0          0               0
# 22              0              0             0          0               0
# 23              0              0             0          0               0
# 24              0              0             0          0               0
# 25              0              0             0          0               0
# ...           ...            ...           ...        ...             ...
# 99487           0              0             0          0               0
# 99488           0              0             0          0               0
# 99489           0              0             0          0               0
# 99490           0              0             0          0               0
# 99491           0              0             0          0               0
#
#        city_sacramento  city_san_antonio  city_san_diego  city_san_francisco  \
# 21                   0                 0               0                   0
# 22                   0                 0               0                   0
# 23                   0                 0               0                   0
# 24                   0                 0               0                   0
# 25                   0                 0               0                   0
# ...                ...               ...             ...                 ...
# 99487                0                 0               0                   0
# 99488                0                 0               0                   0
# 99489                0                 0               1                   0
# 99490                0                 0               0                   0
# 99491                0                 0               1                   0
#
#        city_san_jose  city_santa_ana  city_santa_clarita  city_scottsdale  \
# 21                 0               0                   0                0
# 22                 0               0                   0                0
# 23                 0               0                   0                0
# 24                 0               0                   0                0
# 25                 0               0                   0                0
# ...              ...             ...                 ...              ...
# 99487              0               0                   0                0
# 99488              0               0                   0                0
# 99489              0               0                   0                0
# 99490              0               0                   0                0
# 99491              0               0                   0                0
#
#        city_seattle  city_st_louis  city_st_paul  city_st_petersburg  \
# 21                0              0             0                   0
# 22                0              0             0                   0
# 23                0              0             0                   0
# 24                0              0             0                   0
# 25                0              0             0                   0
# ...             ...            ...           ...                 ...
# 99487             0              0             0                   0
# 99488             0              0             0                   0
# 99489             0              0             0                   0
# 99490             0              0             0                   0
# 99491             0              0             0                   0
#
#        city_stockton  city_tampa  city_toledo  city_tucson  city_tulsa  \
# 21                 0           0            0            0           0
# 22                 0           0            0            0           0
# 23                 0           0            0            0           0
# 24                 0           0            0            0           0
# 25                 0           0            0            0           0
# ...              ...         ...          ...          ...         ...
# 99487              0           0            0            0           0
# 99488              0           0            0            0           0
# 99489              0           0            0            0           0
# 99490              0           0            0            0           0
# 99491              0           0            0            0           0
#
#        city_virginia_beach  city_washington_dc  city_wichita  \
# 21                       0                   0             0
# 22                       0                   0             0
# 23                       0                   0             0
# 24                       0                   0             0
# 25                       0                   0             0
# ...                    ...                 ...           ...
# 99487                    0                   0             0
# 99488                    0                   0             0
# 99489                    0                   0             0
# 99490                    0                   0             0
# 99491                    0                   0             0
#
#        city_winston-salem  body_length  amenities_parking  amenities_gym  \
# 21                      0          152                  1              1
# 22                      0          156                  0              0
# 23                      0          152                  1              0
# 24                      0          154                  1              0
# 25                      0          156                  0              1
# ...                   ...          ...                ...            ...
# 99487                   0         1012                  1              1
# 99488                   0          926                  1              1
# 99489                   0          287                  0              0
# 99490                   0          893                  0              1
# 99491                   0          472                  1              0
#
#        amenities_pool  amenities_washer  photo_thumbnail  pets_dogs  pets_cat  \
# 21                  1                 0                1          0         0
# 22                  1                 0                1          0         0
# 23                  1                 1                1          0         0
# 24                  1                 1                1          0         0
# 25                  1                 0                1          0         0
# ...               ...               ...              ...        ...       ...
# 99487               0                 0                0          0         0
# 99488               1                 1                0          1         1
# 99489               0                 0                0          1         1
# 99490               1                 0                0          1         1
# 99491               0                 0                0          0         0
#
#       orig_state  state_AK  state_AL  state_AR  state_AZ  state_CA  state_CO  \
# 21            TX         0         0         0         0         0         0
# 22            TX         0         0         0         0         0         0
# 23            TX         0         0         0         0         0         0
# 24            TX         0         0         0         0         0         0
# 25            TX         0         0         0         0         0         0
# ...          ...       ...       ...       ...       ...       ...       ...
# 99487         TX         0         0         0         0         0         0
# 99488         FL         0         0         0         0         0         0
# 99489         CA         0         0         0         0         1         0
# 99490         NC         0         0         0         0         0         0
# 99491         CA         0         0         0         0         1         0
#
#        state_CT  state_DC  state_DE  state_FL  state_GA  state_HI  state_IA  \
# 21            0         0         0         0         0         0         0
# 22            0         0         0         0         0         0         0
# 23            0         0         0         0         0         0         0
# 24            0         0         0         0         0         0         0
# 25            0         0         0         0         0         0         0
# ...         ...       ...       ...       ...       ...       ...       ...
# 99487         0         0         0         0         0         0         0
# 99488         0         0         0         1         0         0         0
# 99489         0         0         0         0         0         0         0
# 99490         0         0         0         0         0         0         0
# 99491         0         0         0         0         0         0         0
#
#        state_ID  state_IL  state_IN  state_KS  state_KY  state_LA  state_MA  \
# 21            0         0         0         0         0         0         0
# 22            0         0         0         0         0         0         0
# 23            0         0         0         0         0         0         0
# 24            0         0         0         0         0         0         0
# 25            0         0         0         0         0         0         0
# ...         ...       ...       ...       ...       ...       ...       ...
# 99487         0         0         0         0         0         0         0
# 99488         0         0         0         0         0         0         0
# 99489         0         0         0         0         0         0         0
# 99490         0         0         0         0         0         0         0
# 99491         0         0         0         0         0         0         0
#
#        state_MD  state_ME  state_MI  state_MN  state_MO  state_MS  state_MT  \
# 21            0         0         0         0         0         0         0
# 22            0         0         0         0         0         0         0
# 23            0         0         0         0         0         0         0
# 24            0         0         0         0         0         0         0
# 25            0         0         0         0         0         0         0
# ...         ...       ...       ...       ...       ...       ...       ...
# 99487         0         0         0         0         0         0         0
# 99488         0         0         0         0         0         0         0
# 99489         0         0         0         0         0         0         0
# 99490         0         0         0         0         0         0         0
# 99491         0         0         0         0         0         0         0
#
#        state_NC  state_ND  state_NE  state_NH  state_NJ  state_NM  state_NV  \
# 21            0         0         0         0         0         0         0
# 22            0         0         0         0         0         0         0
# 23            0         0         0         0         0         0         0
# 24            0         0         0         0         0         0         0
# 25            0         0         0         0         0         0         0
# ...         ...       ...       ...       ...       ...       ...       ...
# 99487         0         0         0         0         0         0         0
# 99488         0         0         0         0         0         0         0
# 99489         0         0         0         0         0         0         0
# 99490         1         0         0         0         0         0         0
# 99491         0         0         0         0         0         0         0
#
#        state_NY  state_OH  state_OK  state_OR  state_PA  state_RI  state_SC  \
# 21            0         0         0         0         0         0         0
# 22            0         0         0         0         0         0         0
# 23            0         0         0         0         0         0         0
# 24            0         0         0         0         0         0         0
# 25            0         0         0         0         0         0         0
# ...         ...       ...       ...       ...       ...       ...       ...
# 99487         0         0         0         0         0         0         0
# 99488         0         0         0         0         0         0         0
# 99489         0         0         0         0         0         0         0
# 99490         0         0         0         0         0         0         0
# 99491         0         0         0         0         0         0         0
#
#        state_SD  state_TN  state_TX  state_UT  state_VA  state_VT  state_WA  \
# 21            0         0         1         0         0         0         0
# 22            0         0         1         0         0         0         0
# 23            0         0         1         0         0         0         0
# 24            0         0         1         0         0         0         0
# 25            0         0         1         0         0         0         0
# ...         ...       ...       ...       ...       ...       ...       ...
# 99487         0         0         1         0         0         0         0
# 99488         0         0         0         0         0         0         0
# 99489         0         0         0         0         0         0         0
# 99490         0         0         0         0         0         0         0
# 99491         0         0         0         0         0         0         0
#
#        state_WI  state_WV  state_WY                           price_cat
# 21            0         0         0       02 - Low Price ($1K to $1.2K)
# 22            0         0         0       02 - Low Price ($1K to $1.2K)
# 23            0         0         0          01 - Very Low Price (<$1K)
# 24            0         0         0       02 - Low Price ($1K to $1.2K)
# 25            0         0         0          01 - Very Low Price (<$1K)
# ...         ...       ...       ...                                 ...
# 99487         0         0         0          01 - Very Low Price (<$1K)
# 99488         0         0         0          01 - Very Low Price (<$1K)
# 99489         0         0         0  03 - Medium Price ($1.2K to $1.5K)
# 99490         0         0         0          01 - Very Low Price (<$1K)
# 99491         0         0         0      04 - High Price ($1.5K to $2K)
#
# [82757 rows x 181 columns]

# %%
show_profiles = False
if show_profiles:
    with pd.option_context("display.max_rows", 1000):
        display(RawData[['price_cat'] + feature_vars].groupby('price_cat').mean().apply(lambda s: s.apply('{0:.3f}'.format)).T)

# %%
RawData[['price_cat'] + feature_vars].describe().style.format("{:,.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_dfef5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfef5_level0_col0" class="col_heading level0 col0" >bathrooms</th>
#       <th id="T_dfef5_level0_col1" class="col_heading level0 col1" >bedrooms</th>
#       <th id="T_dfef5_level0_col2" class="col_heading level0 col2" >square_feet</th>
#       <th id="T_dfef5_level0_col3" class="col_heading level0 col3" >body_length</th>
#       <th id="T_dfef5_level0_col4" class="col_heading level0 col4" >amenities_parking</th>
#       <th id="T_dfef5_level0_col5" class="col_heading level0 col5" >amenities_gym</th>
#       <th id="T_dfef5_level0_col6" class="col_heading level0 col6" >amenities_pool</th>
#       <th id="T_dfef5_level0_col7" class="col_heading level0 col7" >amenities_washer</th>
#       <th id="T_dfef5_level0_col8" class="col_heading level0 col8" >photo_thumbnail</th>
#       <th id="T_dfef5_level0_col9" class="col_heading level0 col9" >pets_dogs</th>
#       <th id="T_dfef5_level0_col10" class="col_heading level0 col10" >pets_cat</th>
#       <th id="T_dfef5_level0_col11" class="col_heading level0 col11" >distance_to_closest_city</th>
#       <th id="T_dfef5_level0_col12" class="col_heading level0 col12" >city_albuquerque</th>
#       <th id="T_dfef5_level0_col13" class="col_heading level0 col13" >city_anaheim</th>
#       <th id="T_dfef5_level0_col14" class="col_heading level0 col14" >city_anchorage</th>
#       <th id="T_dfef5_level0_col15" class="col_heading level0 col15" >city_arlington</th>
#       <th id="T_dfef5_level0_col16" class="col_heading level0 col16" >city_atlanta</th>
#       <th id="T_dfef5_level0_col17" class="col_heading level0 col17" >city_aurora</th>
#       <th id="T_dfef5_level0_col18" class="col_heading level0 col18" >city_austin</th>
#       <th id="T_dfef5_level0_col19" class="col_heading level0 col19" >city_bakersfield</th>
#       <th id="T_dfef5_level0_col20" class="col_heading level0 col20" >city_baltimore</th>
#       <th id="T_dfef5_level0_col21" class="col_heading level0 col21" >city_boise</th>
#       <th id="T_dfef5_level0_col22" class="col_heading level0 col22" >city_boston</th>
#       <th id="T_dfef5_level0_col23" class="col_heading level0 col23" >city_buffalo</th>
#       <th id="T_dfef5_level0_col24" class="col_heading level0 col24" >city_chandler</th>
#       <th id="T_dfef5_level0_col25" class="col_heading level0 col25" >city_charlotte</th>
#       <th id="T_dfef5_level0_col26" class="col_heading level0 col26" >city_chesapeake</th>
#       <th id="T_dfef5_level0_col27" class="col_heading level0 col27" >city_chicago</th>
#       <th id="T_dfef5_level0_col28" class="col_heading level0 col28" >city_chula_vista</th>
#       <th id="T_dfef5_level0_col29" class="col_heading level0 col29" >city_cincinnati</th>
#       <th id="T_dfef5_level0_col30" class="col_heading level0 col30" >city_cleveland</th>
#       <th id="T_dfef5_level0_col31" class="col_heading level0 col31" >city_colorado_springs</th>
#       <th id="T_dfef5_level0_col32" class="col_heading level0 col32" >city_columbus</th>
#       <th id="T_dfef5_level0_col33" class="col_heading level0 col33" >city_corpus_christi</th>
#       <th id="T_dfef5_level0_col34" class="col_heading level0 col34" >city_dallas</th>
#       <th id="T_dfef5_level0_col35" class="col_heading level0 col35" >city_denver</th>
#       <th id="T_dfef5_level0_col36" class="col_heading level0 col36" >city_detroit</th>
#       <th id="T_dfef5_level0_col37" class="col_heading level0 col37" >city_durham</th>
#       <th id="T_dfef5_level0_col38" class="col_heading level0 col38" >city_el_paso</th>
#       <th id="T_dfef5_level0_col39" class="col_heading level0 col39" >city_enterprise</th>
#       <th id="T_dfef5_level0_col40" class="col_heading level0 col40" >city_fort_wayne</th>
#       <th id="T_dfef5_level0_col41" class="col_heading level0 col41" >city_fort_worth</th>
#       <th id="T_dfef5_level0_col42" class="col_heading level0 col42" >city_fremont</th>
#       <th id="T_dfef5_level0_col43" class="col_heading level0 col43" >city_fresno</th>
#       <th id="T_dfef5_level0_col44" class="col_heading level0 col44" >city_garland</th>
#       <th id="T_dfef5_level0_col45" class="col_heading level0 col45" >city_gilbert</th>
#       <th id="T_dfef5_level0_col46" class="col_heading level0 col46" >city_glendale</th>
#       <th id="T_dfef5_level0_col47" class="col_heading level0 col47" >city_greensboro</th>
#       <th id="T_dfef5_level0_col48" class="col_heading level0 col48" >city_henderson</th>
#       <th id="T_dfef5_level0_col49" class="col_heading level0 col49" >city_honolulu</th>
#       <th id="T_dfef5_level0_col50" class="col_heading level0 col50" >city_houston</th>
#       <th id="T_dfef5_level0_col51" class="col_heading level0 col51" >city_indianapolis</th>
#       <th id="T_dfef5_level0_col52" class="col_heading level0 col52" >city_irvine</th>
#       <th id="T_dfef5_level0_col53" class="col_heading level0 col53" >city_jacksonville</th>
#       <th id="T_dfef5_level0_col54" class="col_heading level0 col54" >city_jersey_city</th>
#       <th id="T_dfef5_level0_col55" class="col_heading level0 col55" >city_kansas_city</th>
#       <th id="T_dfef5_level0_col56" class="col_heading level0 col56" >city_laredo</th>
#       <th id="T_dfef5_level0_col57" class="col_heading level0 col57" >city_las_vegas</th>
#       <th id="T_dfef5_level0_col58" class="col_heading level0 col58" >city_lexington</th>
#       <th id="T_dfef5_level0_col59" class="col_heading level0 col59" >city_lincoln</th>
#       <th id="T_dfef5_level0_col60" class="col_heading level0 col60" >city_long_beach</th>
#       <th id="T_dfef5_level0_col61" class="col_heading level0 col61" >city_los_angeles</th>
#       <th id="T_dfef5_level0_col62" class="col_heading level0 col62" >city_louisville</th>
#       <th id="T_dfef5_level0_col63" class="col_heading level0 col63" >city_lubbock</th>
#       <th id="T_dfef5_level0_col64" class="col_heading level0 col64" >city_madison</th>
#       <th id="T_dfef5_level0_col65" class="col_heading level0 col65" >city_memphis</th>
#       <th id="T_dfef5_level0_col66" class="col_heading level0 col66" >city_mesa</th>
#       <th id="T_dfef5_level0_col67" class="col_heading level0 col67" >city_miami</th>
#       <th id="T_dfef5_level0_col68" class="col_heading level0 col68" >city_milwaukee</th>
#       <th id="T_dfef5_level0_col69" class="col_heading level0 col69" >city_minneapolis</th>
#       <th id="T_dfef5_level0_col70" class="col_heading level0 col70" >city_nashville</th>
#       <th id="T_dfef5_level0_col71" class="col_heading level0 col71" >city_new_orleans</th>
#       <th id="T_dfef5_level0_col72" class="col_heading level0 col72" >city_new_york_city</th>
#       <th id="T_dfef5_level0_col73" class="col_heading level0 col73" >city_newark</th>
#       <th id="T_dfef5_level0_col74" class="col_heading level0 col74" >city_norfolk</th>
#       <th id="T_dfef5_level0_col75" class="col_heading level0 col75" >city_north_las_vegas</th>
#       <th id="T_dfef5_level0_col76" class="col_heading level0 col76" >city_oakland</th>
#       <th id="T_dfef5_level0_col77" class="col_heading level0 col77" >city_oklahoma_city</th>
#       <th id="T_dfef5_level0_col78" class="col_heading level0 col78" >city_omaha</th>
#       <th id="T_dfef5_level0_col79" class="col_heading level0 col79" >city_orlando</th>
#       <th id="T_dfef5_level0_col80" class="col_heading level0 col80" >city_philadelphia</th>
#       <th id="T_dfef5_level0_col81" class="col_heading level0 col81" >city_phoenix</th>
#       <th id="T_dfef5_level0_col82" class="col_heading level0 col82" >city_pittsburgh</th>
#       <th id="T_dfef5_level0_col83" class="col_heading level0 col83" >city_plano</th>
#       <th id="T_dfef5_level0_col84" class="col_heading level0 col84" >city_portland</th>
#       <th id="T_dfef5_level0_col85" class="col_heading level0 col85" >city_raleigh</th>
#       <th id="T_dfef5_level0_col86" class="col_heading level0 col86" >city_reno</th>
#       <th id="T_dfef5_level0_col87" class="col_heading level0 col87" >city_riverside</th>
#       <th id="T_dfef5_level0_col88"

# %%
## Set up data for model

## Data Processing ##
X = RawData
y = RawData['price']

# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 2024)

print(f"The average price on the training set is ${np.mean(y_train):,.2f}")
print(f"The average price on the test set is ${np.mean(y_test):,.2f}")
# Out:
# The average price on the training set is $1,483.66
# The average price on the test set is $1,487.03

# %%
## Set up table for XGBOOST ##
xgDMatrix = xgb.DMatrix(X[feature_vars], y)
xgbDMatrixTrain = xgb.DMatrix(X_train[feature_vars], y_train)
xgbDMatrixTest = xgb.DMatrix(X_test[feature_vars], y_test)

eval_set = [(xgbDMatrixTest, 'Test'), (xgbDMatrixTrain, 'Train')]
evals_result_base = {}

params = {
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',
    'max_depth': 5,
    'learning_rate':0.30,
    "device": "gpu",
    "tree_method": "hist"
}

# %%
base_model = xgb.train(params = params,
                       dtrain = xgbDMatrixTrain,
                       num_boost_round=1000,
                       evals=eval_set,
                       obj=None,
                       evals_result=evals_result_base,
                       verbose_eval=100)
# Out:
# [0]	Test-rmse:581.26080	Train-rmse:579.38422
# [100]	Test-rmse:310.45274	Train-rmse:287.34542
# [200]	Test-rmse:292.84150	Train-rmse:256.41614
# [300]	Test-rmse:283.79741	Train-rmse:237.07852
# [400]	Test-rmse:277.23645	Train-rmse:221.10396
# [500]	Test-rmse:273.04824	Train-rmse:208.28362
# [600]	Test-rmse:270.21244	Train-rmse:197.15775
# [700]	Test-rmse:268.41985	Train-rmse:189.03563
# [800]	Test-rmse:266.82621	Train-rmse:181.21373
# [900]	Test-rmse:265.62856	Train-rmse:174.03275
# [999]	Test-rmse:264.88395	Train-rmse:168.03213

# %%
# plot learning curves
pyplot.plot(evals_result_base['Train']['rmse'], label='Train')
pyplot.plot(evals_result_base['Test']['rmse'], label='Test')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

# %%
## Check if predictions align with actual (on the test set)
pred_y = base_model.predict(xgbDMatrixTest)

plt.scatter(x = y_test, y = pred_y, alpha=0.2)
plt.title('Actual vs. Predicted Price Points', weight='bold')
plt.xlabel('Actual Price Point')
plt.ylabel('Predicted Price Point')
plt.show()

# %%
################
## Tune model ##
################

# Define the hyperparameter distributions
param_dist = {
     'learning_rate' : [0.01, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30, 0.40],
     'max_depth' : [5, 6, 10, 12, 15, 20, 25, 40, 60],
     'min_child_weight' : [1, 3, 5, 7],
     'gamma': [0.0, 0.1, 0.2 , 0.3, 0.4],
     'colsample_bytree' : [0.3, 0.4, 0.5, 0.7],
     'n_estimators': [20,50,100,200,500,1000]
}

# Create the XGBoost model object
xgb_model = xgb.XGBRegressor(tree_method="hist", device="cuda")

# Create the RandomizedSearchCV object
random_search = RandomizedSearchCV(xgb_model, 
                                   param_distributions=param_dist, 
                                   n_iter=100, 
                                   cv=3, 
                                   scoring='neg_root_mean_squared_error',
                                   verbose = 3)

# Fit the RandomizedSearchCV object to the training data
random_search.fit(cupy.array(X_train[feature_vars]), y_train)

# Print the best set of hyperparameters and the corresponding score
best_hyperparameters = random_search.best_params_
best_score = random_search.best_score_

print("Best set of hyperparameters: ", best_hyperparameters)
print("Best score: ", best_score)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV 1/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.3, max_depth=6, min_child_weight=3, n_estimators=500;, score=-269.379 total time=   1.4s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.3, max_depth=6, min_child_weight=3, n_estimators=500;, score=-270.520 total time=   0.9s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.3, max_depth=6, min_child_weight=3, n_estimators=500;, score=-267.509 total time=   0.9s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.01, max_depth=25, min_child_weight=7, n_estimators=50;, score=-561.854 total time=   1.1s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.01, max_depth=25, min_child_weight=7, n_estimators=50;, score=-576.329 total time=   1.1s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.01, max_depth=25, min_child_weight=7, n_estimators=50;, score=-568.530 total time=   1.1s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=60, min_child_weight=1, n_estimators=50;, score=-483.923 total time=  11.8s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=60, min_child_weight=1, n_estimators=50;, score=-497.668 total time=  11.7s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=60, min_child_weight=1, n_estimators=50;, score=-490.290 total time=  11.7s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=500;, score=-267.563 total time=   7.5s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=500;, score=-269.220 total time=   7.6s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.2, max_depth=15, min_child_weight=1, n_estimators=500;, score=-266.382 total time=   7.7s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.2, max_depth=25, min_child_weight=1, n_estimators=200;, score=-279.821 total time=  17.9s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.2, max_depth=25, min_child_weight=1, n_estimators=200;, score=-282.685 total time=  17.7s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.2, max_depth=25, min_child_weight=1, n_estimators=200;, score=-278.318 total time=  18.2s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.15, max_depth=12, min_child_weight=3, n_estimators=50;, score=-309.260 total time=   0.4s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.15, max_depth=12, min_child_weight=3, n_estimators=50;, score=-313.555 total time=   0.4s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.15, max_depth=12, min_child_weight=3, n_estimators=50;, score=-311.389 total time=   0.4s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.05, max_depth=40, min_child_weight=5, n_estimators=1000;, score=-261.493 total time= 1.2min
# [CV 2/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.05, max_depth=40, min_child_weight=5, n_estimators=1000;, score=-265.407 total time= 1.2min
# [CV 3/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.05, max_depth=40, min_child_weight=5, n_estimators=1000;, score=-261.612 total time= 1.2min
# [CV 1/3] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.15, max_depth=15, min_child_weight=5, n_estimators=500;, score=-261.812 total time=   4.3s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.15, max_depth=15, min_child_weight=5, n_estimators=500;, score=-264.924 total time=   4.3s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.15, max_depth=15, min_child_weight=5, n_estimators=500;, score=-261.419 total time=   4.4s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.4, max_depth=60, min_child_weight=7, n_estimators=20;, score=-292.339 total time=   1.9s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.4, max_depth=60, min_child_weight=7, n_estimators=20;, score=-294.540 total time=   1.9s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.4, max_depth=60, min_child_weight=7, n_estimators=20;, score=-295.827 total time=   1.9s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=25, min_child_weight=1, n_estimators=500;, score=-266.495 total time=  40.6s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=25, min_child_weight=1, n_estimators=500;, score=-270.200 total time=  40.1s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=25, min_child_weight=1, n_estimators=500;, score=-268.440 total time=  40.1s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.4, max_depth=10, min_child_weight=3, n_estimators=500;, score=-276.244 total time=   2.3s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.4, max_depth=10, min_child_weight=3, n_estimators=500;, score=-276.129 total time=   2.3s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.4, max_depth=10, min_child_weight=3, n_estimators=500;, score=-272.631 total time=   2.3s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=60, min_child_weight=5, n_estimators=100;, score=-267.213 total time=  12.6s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=60, min_child_weight=5, n_estimators=100;, score=-270.571 total time=  12.6s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=60, min_child_weight=5, n_estimators=100;, score=-269.117 total time=  12.7s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.15, max_depth=5, min_child_weight=5, n_estimators=1000;, score=-269.531 total time=   1.5s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.15, max_depth=5, min_child_weight=5, n_estimators=1000;, score=-272.792 total time=   1.5s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.15, max_depth=5, min_child_weight=5, n_estimators=1000;, score=-270.269 total time=   1.5s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=20;, score=-401.818 total time=   0.1s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=20;, score=-413.359 total time=   0.1s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=20;, score=-408.682 total time=   0.1s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=1000;, score=-324.261 total time=   2.0s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=1000;, score=-329.334 total time=   2.0s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=1000;, score=-327.486 total time=   2.0s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=20;, score=-290.181 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=20;, score=-295.889 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.25, max_depth=20, min_child_weight=7, n_estimators=20;, score=-292.403 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=40, min_child_weight=3, n_estimators=50;, score=-300.327 total time=   3.7s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=40, min_child_weight=3, n_estimators=50;, score=-305.645 total time=   3.7s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.3, max_depth=40, min_child_weight=3, n_estimators=50;, score=-299.137 total time=   3.7s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=200;, score=-278.918 total time=   6.2s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=200;, score=-281.859 total time=   6.1s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=25, min_child_weight=5, n_estimators=200;, score=-277.681 total time=   6.4s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=50;, score=-340.810 total time=   0.4s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=50;, score=-348.352 total time=   0.4s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=50;, score=-345.748 total time=   0.4s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=500;, score=-269.353 total time=   2.4s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=500;, score=-272.458 total time=   2.3s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=500;, score=-269.607 total time=   2.3s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=100;, score=-283.148 total time=   0.4s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=100;, score=-284.362 total time=   0.4s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=100;, score=-281.191 total time=   0.4s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.25, max_depth=15, min_child_weight=5, n_estimators=100;, score=-268.612 total time=   1.3s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.25, max_depth=15, min_child_weight=5, n_estimators=100;, score=-271.263 total time=   1.3s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.25, max_depth=15, min_child_weight=5, n_estimators=100;, score=-267.290 total time=   1.2s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.15, max_depth=15, min_child_weight=5, n_estimators=100;, score=-273.205 total time=   1.2s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.15, max_depth=15, min_child_weight=5, n_estimators=100;, score=-276.142 total time=   1.2s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.15, max_depth=15, min_child_weight=5, n_estimators=100;, score=-273.729 total time=   1.2s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=20;, score=-602.512 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=20;, score=-616.997 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.01, max_depth=15, min_child_weight=1, n_estimators=20;, score=-608.938 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.25, max_depth=12, min_child_weight=7, n_estimators=100;, score=-275.379 total time=   0.6s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.25, max_depth=12, min_child_weight=7, n_estimators=100;, score=-278.004 total time=   0.6s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.25, max_depth=12, min_child_weight=7, n_estimators=100;, score=-276.443 total time=   0.6s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.05, max_depth=15, min_child_weight=7, n_estimators=100;, score=-282.534 total time=   2.1s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.05, max_depth=15, min_child_weight=7, n_estimators=100;, score=-286.028 total time=   2.0s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.05, max_depth=15, min_child_weight=7, n_estimators=100;, score=-284.728 total time=   2.0s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=100;, score=-271.834 total time=   1.0s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=100;, score=-276.516 total time=   1.0s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.25, max_depth=15, min_child_weight=7, n_estimators=100;, score=-274.267 total time=   1.0s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.25, max_depth=60, min_child_weight=5, n_estimators=1000;, score=-290.360 total time= 1.7min
# [CV 2/3] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.25, max_depth=60, min_child_weight=5, n_estimators=1000;, score=-294.334 total time= 1.8min
# [CV 3/3] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.25, max_depth=60, min_child_weight=5, n_estimators=1000;, score=-289.191 total time= 1.8min
# [CV 1/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.15, max_depth=60, min_child_weight=5, n_estimators=100;, score=-274.450 total time=  10.0s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.15, max_depth=60, min_child_weight=5, n_estimators=100;, score=-280.229 total time=  10.1s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.15, max_depth=60, min_child_weight=5, n_estimators=100;, score=-275.399 total time=  10.0s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.3, max_depth=40, min_child_weight=5, n_estimators=500;, score=-293.560 total time=  21.6s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.3, max_depth=40, min_child_weight=5, n_estimators=500;, score=-295.333 total time=  22.3s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.3, max_depth=40, min_child_weight=5, n_estimators=500;, score=-289.480 total time=  22.3s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=50;, score=-336.230 total time=   0.0s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=50;, score=-341.824 total time=   0.0s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.4, max_depth=5, min_child_weight=1, n_estimators=50;, score=-335.006 total time=   0.0s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.05, max_depth=25, min_child_weight=7, n_estimators=50;, score=-369.610 total time=   1.2s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.05, max_depth=25, min_child_weight=7, n_estimators=50;, score=-381.454 total time=   1.2s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.05, max_depth=25, min_child_weight=7, n_estimators=50;, score=-375.485 total time=   1.2s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=200;, score=-360.072 total time=   1.7s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=200;, score=-367.513 total time=   1.8s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=200;, score=-365.406 total time=   1.8s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=200;, score=-309.342 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=200;, score=-313.841 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=200;, score=-311.839 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.25, max_depth=40, min_child_weight=1, n_estimators=50;, score=-285.856 total time=  15.3s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.25, max_depth=40, min_child_weight=1, n_estimators=50;, score=-291.296 total time=  14.8s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.25, max_depth=40, min_child_weight=1, n_estimators=50;, score=-290.686 total time=  14.7s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.4, max_depth=60, min_child_weight=1, n_estimators=1000;, score=-305.870 total time=  15.0s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.4, max_depth=60, min_child_weight=1, n_estimators=1000;, score=-309.014 total time=  15.2s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.4, max_depth=60, min_child_weight=1, n_estimators=1000;, score=-310.974 total time=  15.0s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.4, max_depth=20, min_child_weight=1, n_estimators=100;, score=-299.917 total time=   4.4s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.4, max_depth=20, min_child_weight=1, n_estimators=100;, score=-299.435 total time=   4.5s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.4, max_depth=20, min_child_weight=1, n_estimators=100;, score=-292.889 total time=   4.4s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.15, max_depth=40, min_child_weight=5, n_estimators=1000;, score=-272.887 total time=  34.4s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.15, max_depth=40, min_child_weight=5, n_estimators=1000;, score=-276.372 total time=  33.9s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.15, max_depth=40, min_child_weight=5, n_estimators=1000;, score=-271.811 total time=  33.1s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=1000;, score=-339.097 total time=   1.6s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=1000;, score=-345.316 total time=   1.5s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=1000;, score=-341.474 total time=   1.6s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.15, max_depth=40, min_child_weight=1, n_estimators=1000;, score=-287.680 total time=  33.8s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.15, max_depth=40, min_child_weight=1, n_estimators=1000;, score=-291.645 total time=  34.1s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.15, max_depth=40, min_child_weight=1, n_estimators=1000;, score=-287.513 total time=  34.4s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=100;, score=-337.449 total time=   0.1s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=100;, score=-342.456 total time=   0.1s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=100;, score=-339.169 total time=   0.1s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.25, max_depth=5, min_child_weight=5, n_estimators=50;, score=-334.967 total time=   0.0s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.25, max_depth=5, min_child_weight=5, n_estimators=50;, score=-342.539 total time=   0.0s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.25, max_depth=5, min_child_weight=5, n_estimators=50;, score=-337.488 total time=   0.0s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.15, max_depth=20, min_child_weight=1, n_estimators=1000;, score=-271.529 total time=  41.4s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.15, max_depth=20, min_child_weight=1, n_estimators=1000;, score=-275.039 total time=  40.0s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.15, max_depth=20, min_child_weight=1, n_estimators=1000;, score=-269.461 total time=  41.3s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.25, max_depth=15, min_child_weight=3, n_estimators=20;, score=-291.178 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.25, max_depth=15, min_child_weight=3, n_estimators=20;, score=-294.224 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.25, max_depth=15, min_child_weight=3, n_estimators=20;, score=-292.991 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.25, max_depth=25, min_child_weight=3, n_estimators=1000;, score=-281.101 total time=  17.7s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.25, max_depth=25, min_child_weight=3, n_estimators=1000;, score=-282.653 total time=  17.5s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.25, max_depth=25, min_child_weight=3, n_estimators=1000;, score=-278.801 total time=  17.3s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=3, n_estimators=100;, score=-304.669 total time=   0.1s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=3, n_estimators=100;, score=-306.942 total time=   0.1s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.4, max_depth=5, min_child_weight=3, n_estimators=100;, score=-305.343 total time=   0.1s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.25, max_depth=60, min_child_weight=3, n_estimators=100;, score=-293.845 total time=   8.4s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.25, max_depth=60, min_child_weight=3, n_estimators=100;, score=-295.221 total time=   8.4s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.25, max_depth=60, min_child_weight=3, n_estimators=100;, score=-292.527 total time=   8.4s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=25, min_child_weight=3, n_estimators=200;, score=-275.484 total time=   7.2s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=25, min_child_weight=3, n_estimators=200;, score=-279.435 total time=   7.5s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.2, max_depth=25, min_child_weight=3, n_estimators=200;, score=-273.295 total time=   7.3s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.25, max_depth=6, min_child_weight=7, n_estimators=50;, score=-321.668 total time=   0.0s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.25, max_depth=6, min_child_weight=7, n_estimators=50;, score=-327.692 total time=   0.0s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.25, max_depth=6, min_child_weight=7, n_estimators=50;, score=-321.501 total time=   0.0s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.3, max_depth=60, min_child_weight=1, n_estimators=100;, score=-331.254 total time=  20.7s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.3, max_depth=60, min_child_weight=1, n_estimators=100;, score=-334.794 total time=  20.6s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.3, max_depth=60, min_child_weight=1, n_estimators=100;, score=-331.496 total time=  20.7s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.15, max_depth=40, min_child_weight=3, n_estimators=200;, score=-276.634 total time=  22.0s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.15, max_depth=40, min_child_weight=3, n_estimators=200;, score=-282.204 total time=  21.6s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.15, max_depth=40, min_child_weight=3, n_estimators=200;, score=-276.311 total time=  22.1s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=60, min_child_weight=5, n_estimators=500;, score=-285.882 total time=  17.5s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=60, min_child_weight=5, n_estimators=500;, score=-289.244 total time=  18.6s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=60, min_child_weight=5, n_estimators=500;, score=-286.907 total time=  17.8s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=20, min_child_weight=5, n_estimators=100;, score=-266.620 total time=   3.2s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=20, min_child_weight=5, n_estimators=100;, score=-268.654 total time=   3.2s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=20, min_child_weight=5, n_estimators=100;, score=-266.545 total time=   3.2s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.4, max_depth=60, min_child_weight=1, n_estimators=500;, score=-351.078 total time=  15.6s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.4, max_depth=60, min_child_weight=1, n_estimators=500;, score=-355.808 total time=  15.4s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.4, max_depth=60, min_child_weight=1, n_estimators=500;, score=-353.258 total time=  16.4s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.2, max_depth=60, min_child_weight=5, n_estimators=200;, score=-282.317 total time=  19.5s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.2, max_depth=60, min_child_weight=5, n_estimators=200;, score=-286.510 total time=  19.5s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.2, max_depth=60, min_child_weight=5, n_estimators=200;, score=-282.300 total time=  19.2s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.4, max_depth=25, min_child_weight=5, n_estimators=1000;, score=-291.088 total time=  14.9s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.4, max_depth=25, min_child_weight=5, n_estimators=1000;, score=-293.908 total time=  15.2s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.4, max_depth=25, min_child_weight=5, n_estimators=1000;, score=-288.352 total time=  14.1s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.01, max_depth=25, min_child_weight=1, n_estimators=100;, score=-454.720 total time=   7.6s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.01, max_depth=25, min_child_weight=1, n_estimators=100;, score=-467.976 total time=   7.5s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.01, max_depth=25, min_child_weight=1, n_estimators=100;, score=-460.507 total time=   7.6s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.25, max_depth=6, min_child_weight=5, n_estimators=500;, score=-274.745 total time=   0.9s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.25, max_depth=6, min_child_weight=5, n_estimators=500;, score=-275.832 total time=   0.9s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.25, max_depth=6, min_child_weight=5, n_estimators=500;, score=-275.330 total time=   0.9s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=60, min_child_weight=5, n_estimators=200;, score=-267.712 total time=  24.8s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=60, min_child_weight=5, n_estimators=200;, score=-270.299 total time=  25.4s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=60, min_child_weight=5, n_estimators=200;, score=-269.456 total time=  25.2s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=1000;, score=-339.328 total time=   1.6s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=1000;, score=-345.216 total time=   1.6s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=1000;, score=-342.024 total time=   1.6s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.25, max_depth=20, min_child_weight=3, n_estimators=500;, score=-269.486 total time=  11.8s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.25, max_depth=20, min_child_weight=3, n_estimators=500;, score=-274.223 total time=  12.9s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.25, max_depth=20, min_child_weight=3, n_estimators=500;, score=-269.654 total time=  11.8s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=50;, score=-294.079 total time=   0.8s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=50;, score=-298.778 total time=   0.8s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=12, min_child_weight=1, n_estimators=50;, score=-297.329 total time=   0.8s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.05, max_depth=25, min_child_weight=3, n_estimators=500;, score=-260.737 total time=  22.0s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.05, max_depth=25, min_child_weight=3, n_estimators=500;, score=-265.874 total time=  22.2s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.05, max_depth=25, min_child_weight=3, n_estimators=500;, score=-260.474 total time=  24.0s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=500;, score=-265.035 total time=   2.4s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=500;, score=-268.542 total time=   2.5s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.3, max_depth=10, min_child_weight=3, n_estimators=500;, score=-266.582 total time=   2.4s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=1000;, score=-268.928 total time=   1.5s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=1000;, score=-270.176 total time=   1.5s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=1000;, score=-268.805 total time=   1.5s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=500;, score=-259.292 total time=   2.6s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=500;, score=-259.306 total time=   2.6s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.2, max_depth=10, min_child_weight=3, n_estimators=500;, score=-259.569 total time=   2.6s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.3, max_depth=60, min_child_weight=1, n_estimators=500;, score=-331.275 total time=  20.5s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.3, max_depth=60, min_child_weight=1, n_estimators=500;, score=-334.835 total time=  20.3s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.3, max_depth=60, min_child_weight=1, n_estimators=500;, score=-331.558 total time=  20.3s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=1000;, score=-263.764 total time= 1.1min
# [CV 2/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=1000;, score=-268.363 total time= 1.1min
# [CV 3/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=20, min_child_weight=1, n_estimators=1000;, score=-264.565 total time= 1.1min
# [CV 1/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=1000;, score=-268.456 total time=   1.9s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=1000;, score=-271.240 total time=   1.9s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.1, max_depth=6, min_child_weight=5, n_estimators=1000;, score=-268.173 total time=   1.9s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=1000;, score=-289.768 total time=   1.8s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=1000;, score=-292.397 total time=   1.8s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.05, max_depth=6, min_child_weight=5, n_estimators=1000;, score=-289.036 total time=   1.8s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=20;, score=-628.466 total time=   0.0s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=20;, score=-643.164 total time=   0.0s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=20;, score=-635.272 total time=   0.0s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=20, min_child_weight=7, n_estimators=200;, score=-315.887 total time=   8.0s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=20, min_child_weight=7, n_estimators=200;, score=-323.558 total time=   8.1s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.01, max_depth=20, min_child_weight=7, n_estimators=200;, score=-319.421 total time=   8.1s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=12, min_child_weight=3, n_estimators=20;, score=-391.832 total time=   0.2s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=12, min_child_weight=3, n_estimators=20;, score=-403.534 total time=   0.2s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=12, min_child_weight=3, n_estimators=20;, score=-397.705 total time=   0.1s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.15, max_depth=60, min_child_weight=1, n_estimators=200;, score=-298.604 total time= 1.0min
# [CV 2/3] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.15, max_depth=60, min_child_weight=1, n_estimators=200;, score=-304.078 total time= 1.0min
# [CV 3/3] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.15, max_depth=60, min_child_weight=1, n_estimators=200;, score=-299.834 total time= 1.0min
# [CV 1/3] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.2, max_depth=20, min_child_weight=3, n_estimators=100;, score=-268.996 total time=   3.3s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.2, max_depth=20, min_child_weight=3, n_estimators=100;, score=-271.119 total time=   3.3s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.2, max_depth=20, min_child_weight=3, n_estimators=100;, score=-267.229 total time=   3.3s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.25, max_depth=20, min_child_weight=1, n_estimators=50;, score=-284.498 total time=   2.6s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.25, max_depth=20, min_child_weight=1, n_estimators=50;, score=-287.336 total time=   2.7s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.25, max_depth=20, min_child_weight=1, n_estimators=50;, score=-282.304 total time=   2.6s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.25, max_depth=25, min_child_weight=7, n_estimators=500;, score=-273.630 total time=   9.6s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.25, max_depth=25, min_child_weight=7, n_estimators=500;, score=-277.698 total time=   9.3s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.25, max_depth=25, min_child_weight=7, n_estimators=500;, score=-272.488 total time=   9.7s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=200;, score=-278.632 total time=   0.7s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=200;, score=-279.747 total time=   0.7s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.3, max_depth=10, min_child_weight=7, n_estimators=200;, score=-277.474 total time=   0.7s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=200;, score=-268.743 total time=   1.1s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=200;, score=-270.501 total time=   1.1s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=200;, score=-267.595 total time=   1.1s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.25, max_depth=15, min_child_weight=1, n_estimators=100;, score=-279.731 total time=   1.7s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.25, max_depth=15, min_child_weight=1, n_estimators=100;, score=-280.836 total time=   1.7s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.25, max_depth=15, min_child_weight=1, n_estimators=100;, score=-277.939 total time=   1.7s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=25, min_child_weight=7, n_estimators=200;, score=-263.596 total time=   5.4s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=25, min_child_weight=7, n_estimators=200;, score=-266.556 total time=   5.4s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=25, min_child_weight=7, n_estimators=200;, score=-262.735 total time=   5.4s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=1000;, score=-261.691 total time=  45.3s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=1000;, score=-265.585 total time=  45.0s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=20, min_child_weight=1, n_estimators=1000;, score=-260.473 total time=  46.6s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.2, max_depth=40, min_child_weight=7, n_estimators=200;, score=-275.185 total time=  10.3s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.2, max_depth=40, min_child_weight=7, n_estimators=200;, score=-279.141 total time=  10.6s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.2, max_depth=40, min_child_weight=7, n_estimators=200;, score=-275.877 total time=  10.5s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=25, min_child_weight=1, n_estimators=100;, score=-268.467 total time=  13.7s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=25, min_child_weight=1, n_estimators=100;, score=-271.942 total time=  13.8s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=25, min_child_weight=1, n_estimators=100;, score=-270.232 total time=  13.9s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=100;, score=-297.248 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=100;, score=-300.528 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=100;, score=-296.873 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=60, min_child_weight=3, n_estimators=20;, score=-339.845 total time=   1.1s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=60, min_child_weight=3, n_estimators=20;, score=-349.745 total time=   1.1s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=60, min_child_weight=3, n_estimators=20;, score=-343.730 total time=   1.1s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=60, min_child_weight=3, n_estimators=50;, score=-484.184 total time=   6.5s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=60, min_child_weight=3, n_estimators=50;, score=-497.835 total time=   6.5s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.01, max_depth=60, min_child_weight=3, n_estimators=50;, score=-490.481 total time=   6.4s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.4, max_depth=10, min_child_weight=5, n_estimators=1000;, score=-275.312 total time=   4.6s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.4, max_depth=10, min_child_weight=5, n_estimators=1000;, score=-275.349 total time=   4.6s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.4, max_depth=10, min_child_weight=5, n_estimators=1000;, score=-273.407 total time=   4.7s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=40, min_child_weight=3, n_estimators=500;, score=-285.032 total time=  14.8s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=40, min_child_weight=3, n_estimators=500;, score=-289.666 total time=  14.5s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.3, max_depth=40, min_child_weight=3, n_estimators=500;, score=-291.116 total time=  14.6s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=1000;, score=-257.024 total time=   6.2s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=1000;, score=-258.208 total time=   6.3s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=1000;, score=-256.814 total time=   6.2s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.1, max_depth=40, min_child_weight=1, n_estimators=100;, score=-271.957 total time=  36.0s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.1, max_depth=40, min_child_weight=1, n_estimators=100;, score=-275.778 total time=  36.1s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.1, max_depth=40, min_child_weight=1, n_estimators=100;, score=-273.988 total time=  36.4s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.4, max_depth=25, min_child_weight=5, n_estimators=20;, score=-296.494 total time=   0.7s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.4, max_depth=25, min_child_weight=5, n_estimators=20;, score=-299.219 total time=   0.7s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.4, max_depth=25, min_child_weight=5, n_estimators=20;, score=-293.548 total time=   0.8s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=200;, score=-286.568 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=200;, score=-292.927 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=200;, score=-287.635 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=40, min_child_weight=5, n_estimators=1000;, score=-267.370 total time=  43.5s
# [CV 2/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=40, min_child_weight=5, n_estimators=1000;, score=-270.198 total time=  47.1s
# [CV 3/3] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=40, min_child_weight=5, n_estimators=1000;, score=-268.173 total time=  46.4s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=25, min_child_weight=1, n_estimators=100;, score=-280.116 total time=  10.0s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=25, min_child_weight=1, n_estimators=100;, score=-282.753 total time=   9.2s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=25, min_child_weight=1, n_estimators=100;, score=-278.177 total time=   9.5s
# [CV 1/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=20;, score=-494.881 total time=   0.0s
# [CV 2/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=20;, score=-506.824 total time=   0.0s
# [CV 3/3] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=20;, score=-500.501 total time=   0.0s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.15, max_depth=12, min_child_weight=7, n_estimators=100;, score=-281.087 total time=   0.7s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.15, max_depth=12, min_child_weight=7, n_estimators=100;, score=-284.270 total time=   0.7s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.15, max_depth=12, min_child_weight=7, n_estimators=100;, score=-281.778 total time=   0.7s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=20, min_child_weight=3, n_estimators=50;, score=-293.964 total time=   1.5s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=20, min_child_weight=3, n_estimators=50;, score=-299.471 total time=   1.5s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.15, max_depth=20, min_child_weight=3, n_estimators=50;, score=-295.686 total time=   1.5s
# [CV 1/3] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.1, max_depth=60, min_child_weight=5, n_estimators=100;, score=-273.948 total time=   8.2s
# [CV 2/3] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.1, max_depth=60, min_child_weight=5, n_estimators=100;, score=-278.893 total time=   8.2s
# [CV 3/3] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.1, max_depth=60, min_child_weight=5, n_estimators=100;, score=-274.523 total time=   8.2s
# [CV 1/3] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.1, max_depth=25, min_child_weight=1, n_estimators=200;, score=-273.606 total time=  15.7s
# [CV 2/3] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.1, max_depth=25, min_child_weight=1, n_estimators=200;, score=-278.814 total time=  15.3s
# [CV 3/3] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.1, max_depth=25, min_child_weight=1, n_estimators=200;, score=-273.717 total time=  15.6s
# Best set of hyperparameters:  {'n_estimators': 1000, 'min_child_weight': 7, 'max_depth': 12, 'learning_rate': 0.1, 'gamma': 0.4, 'colsample_bytree': 0.7}
# Best score:  -257.3486445568441

# %%
## Need to tweak one parameter
evals_result_optimized = {'n_estimators': 1000, 'min_child_weight': 7, 'max_depth': 12, 'learning_rate': 0.1, 'gamma': 0.4, 'colsample_bytree': 0.7}

try:
    opt_num_rounds = best_hyperparameters['n_estimators']
    del best_hyperparameters['n_estimators']
except:
    None

model_optimized = xgb.train(params = best_hyperparameters,
                            dtrain = xgDMatrix,
                            evals=eval_set,
                            num_boost_round=opt_num_rounds,
                            obj=None,
                            evals_result=evals_result_optimized,
                            verbose_eval=100)
# Out:
# [0]	Test-rmse:628.03899	Train-rmse:627.06262
# [100]	Test-rmse:216.74603	Train-rmse:211.25877
# [200]	Test-rmse:187.09220	Train-rmse:182.48444
# [300]	Test-rmse:165.43089	Train-rmse:161.33926
# [400]	Test-rmse:146.33988	Train-rmse:143.00175
# [500]	Test-rmse:132.28431	Train-rmse:129.14924
# [600]	Test-rmse:121.21621	Train-rmse:118.54136
# [700]	Test-rmse:110.27720	Train-rmse:108.01982
# [800]	Test-rmse:104.14856	Train-rmse:101.82425
# [900]	Test-rmse:97.29706	Train-rmse:95.22172
# [999]	Test-rmse:89.89846	Train-rmse:88.16165

# %%
## Let's see how the optimized model compares to the base model
pyplot.plot(evals_result_base['Test']['rmse'], label='Base (test)')
pyplot.plot(evals_result_optimized['Test']['rmse'], label='Optimimized (tet)')

pyplot.title('Learning Curves for Base vs. Optimized XGB Model')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

# %%
##########
## Shap ##
##########

sample_x_test = X_test.sample(10000)
explainer = shap.Explainer(model_optimized, sample_x_test)

# Calculate SHAP values
shap_values = explainer(sample_x_test)

# Visualize the SHAP values (optional)
shap.summary_plot(shap_values, sample_x_test)

# %%
new_category_names = [
                    'Very Low (<$1K)',
                    'Low (\\$1K to \\$1.2K)',
                    'Medium (\\$1.2K to \\$1.5K)',
                    'High (\\$1.5K to \\$2K)',
                    'Very High (\\$2K to \\$3K)',
                    'Premium (\\$3K+)'
                   ]

## Boxplot
predicted_price = pd.DataFrame({'price_actual':y_test,
                                'price':pred_y_test['predicted_price']})

predicted_price = ab.create_price_bins(df=predicted_price, print_results=False, category_names=new_category_names)

predicted_price.rename(columns={'price_cat': 'Predicted Price Category'}, inplace=True)


sns.set(rc={'figure.figsize':(11,8)}, font_scale=0.8, style='whitegrid')
sns.boxplot(data=predicted_price, 
            x='Predicted Price Category', 
            y='price_actual',
            order = new_category_names,
            width=0.6,
            whis=0.95).set(
    xlabel='Predicted Price Bucket', 
    ylabel='Actual Rent Price'
)
plt.title('Distribution of Actual Rent Prices by Predicted Groups')
plt.show()

# %%
sns.kdeplot(
   data=predicted_price, x="price_actual", hue='Predicted Price Category',
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0, hue_order=new_category_names).set(
    xlabel='Actual Rent Price', 
)
plt.title('Distribution of Actual Rent Prices by Predicted Groups')
plt.show()

# %%
print("hello")

# %%
## TO Export:
pred_y_test  = base_model.predict(xgbDMatrixTest)
pred_y_train = base_model.predict(xgbDMatrixTrain)

pred_y_test = pd.DataFrame({'predicted_price': pred_y_test,
                            'actual_price': y_test},  index=X_test.index)
pred_y_train = pd.DataFrame({'predicted_price': pred_y_train,
                            'actual_price': y_train},  index=X_train.index)

test_full = pd.concat([X_test, pred_y_test], axis = 1)
test_full['train_vs_test'] = 'Test'

train_full = pd.concat([X_train, pred_y_train], axis = 1)
train_full['train_vs_test'] = 'Train'

final_export = pd.concat([test_full, train_full], axis = 0)

################################
## Create Columns for Tableau ##
################################

bedroom_conditions = [
    (final_export['bedrooms'] == 0),
    (final_export['bedrooms'] == 1),
    (final_export['bedrooms'] == 2),
    (final_export['bedrooms'] == 3),
    (final_export['bedrooms'] >= 4)
]

bedroom_names = [
    '01 - Studio',
    '02 - One Bedroom',
    '03 - Two Bedrooms',
    '04 - Three Bedrooms',
    '05 - Four or more',
]

size_conditions = [
    (final_export['square_feet'] < 700),
    (final_export['square_feet'] >= 700) & (final_export['square_feet'] < 850),
    (final_export['square_feet'] >= 850) & (final_export['square_feet'] < 1000),
    (final_export['square_feet'] >= 1000)
]

size_names = [
    '01 - Small (<700sqft)',
    '02 - Medium (700 to 850sqft)',
    '03 - Large (850 to 1,000sqft)',
    '04 - Very large (1,000sqft+)',
]

city_distance_conditions = [
    (final_export['distance_to_closest_city'] < 0.11),
    (final_export['distance_to_closest_city'] >= 0.11) & (final_export['distance_to_closest_city'] < 0.26),
    (final_export['distance_to_closest_city'] >= 0.26)
]

city_distance_names = [
    '01 - Close',
    '02 - Medium',
    '03 - Far',
]

body_length_conditions = [
    (final_export['body_length'] < 860),
    (final_export['body_length'] >= 860) & (final_export['body_length'] < 1000),
    (final_export['body_length'] >= 1000)
]

body_length_distance_names = [
    '01 - Short',
    '02 - Medium',
    '03 - Long',
]

actual_price_conditions = [
        (final_export['actual_price'] < 1000),
        (final_export['actual_price'] >= 1000) & (final_export['actual_price'] < 1200),
        (final_export['actual_price'] >= 1200) & (final_export['actual_price'] < 1500),
        (final_export['actual_price'] >= 1500) & (final_export['actual_price'] < 2000),
        (final_export['actual_price'] >= 2000) & (final_export['actual_price'] < 3000),
        (final_export['actual_price'] >= 3000)
    ]

predicted_price_conditions = [
        (final_export['predicted_price'] < 1000),
        (final_export['predicted_price'] >= 1000) & (final_export['predicted_price'] < 1200),
        (final_export['predicted_price'] >= 1200) & (final_export['predicted_price'] < 1500),
        (final_export['predicted_price'] >= 1500) & (final_export['predicted_price'] < 2000),
        (final_export['predicted_price'] >= 2000) & (final_export['predicted_price'] < 3000),
        (final_export['predicted_price'] >= 3000)
    ]

price_names = [
            '01 - Very Low Price (<$1K)',
            '02 - Low Price ($1K to $1.2K)',
            '03 - Medium Price ($1.2K to $1.5K)',
            '04 - High Price ($1.5K to $2K)',
            '05 - Very High Price ($2K to ß$3K)',
            '06 - Highly Premium ($3K+)'
            ]

## Price
final_export['predicted_price_cat'] = np.select(predicted_price_conditions, price_names, default='Unknown')
final_export['actual_price_cat'] = np.select(actual_price_conditions, price_names, default='Unknown')

## Unit Description
final_export['bedroom_cat'] = np.select(bedroom_conditions, bedroom_names, default='Unknown')
final_export['size_cat'] = np.select(size_conditions, size_names, default='Unknown')
final_export['distance_cat'] = np.select(city_distance_conditions, city_distance_names, default='Unknown')

## Pets
final_export['allows_cat'] = final_export['pets_cat'].apply(lambda x: 'Yes' if x == 1 else 'No')
final_export['allows_dogs'] = final_export['pets_dogs'].apply(lambda x: 'Yes' if x == 1 else 'No')

## Presentation
final_export['has_photo'] = final_export['photo_thumbnail'].apply(lambda x: 'Yes' if x == 1 else 'No')
final_export['body_length_cat'] = np.select(body_length_conditions, body_length_distance_names, default='Unknown')

## Amenities
final_export['has_parking'] = final_export['amenities_parking'].apply(lambda x: 'Yes' if x == 1 else 'No')
final_export['has_gym'] = final_export['amenities_gym'].apply(lambda x: 'Yes' if x == 1 else 'No')
final_export['has_pool'] = final_export['amenities_pool'].apply(lambda x: 'Yes' if x == 1 else 'No')
final_export['has_washer'] = final_export['amenities_washer'].apply(lambda x: 'Yes' if x == 1 else 'No')

## Drop all the city/state metrics
final_export.drop([text for text in all_columns if re.search('^city_', text)], axis=1, inplace=True)
final_export.drop([text for text in all_columns if re.search('^state_', text)], axis=1, inplace=True)

# %%
## More Profiling

top_5_cities = ['city_new_york_city', 'city_los_angeles', 'city_chicago', 'city_houston', 'city_phoenix']

top_6_to_20_cities = ['city_philadelphia', 'city_san_antonio', 'city_san_diego', 'city_dallas', 'city_san_jose',
                      'city_austin', 'city_jacksonville', 'city_fort_worth', 'city_columbus', 'city_charlotte',
                      'city_indianapolis', 'city_san_francisco', 'city_seattle', 'city_denver', 'city_washington_DC']

nearest_city_conditions = [
        final_export['orig_closest_city'].isin(top_5_cities),
        final_export['orig_closest_city'].isin(top_6_to_20_cities)
    ]

nearest_city_names = [
            '01 - Nearest City: Top 5',
            '02 - Nearest City: Top 6 to 20'
            ]

northwest_states = ["AK",	"OR",	"WA"]
west_states = ["CA",	"CO",	"HI",	"UT"]
southwest_states = ["AZ",	"NM",	"NV"]
midwest_states = ["IA",	"ID",	"IL",	"IN",	"KS",	"MI",	"MN",	"MO",	"MT",	"ND",	"NE",	"OH",	"SD",	"WI",	"WY"]
northeast_states = ["CT",	"DC",	"DE",	"MA",	"MD",	"ME",	"NH",	"NJ",	"NY",	"PA",	"RI",	"VT"]
south_states = ["AL",	"AR",	"FL",	"GA",	"KY",	"LA",	"MS",	"NC",	"OK",	"SC",	"TN",	"TX",	"VA",	"WV"]

region_conditions = [
        final_export['orig_state'].isin(northwest_states),
        final_export['orig_state'].isin(west_states),
        final_export['orig_state'].isin(southwest_states),
        final_export['orig_state'].isin(midwest_states),
        final_export['orig_state'].isin(northeast_states),
        final_export['orig_state'].isin(south_states),
    ]

region_names = [
            '01 - Northwest',
            '02 - West',
            '03 - Southwest',
            '04 - Midwest',
            '05 - Northeast',
            '06 - South'
            ]

final_export['nearest_city_cat'] = np.select(nearest_city_conditions, nearest_city_names, default='03 - Nearest City: Not Top 20')
final_export['state_cat'] = np.select(region_conditions, region_names, default='Unknown')

## Drop title and body
final_export.drop(['category', 'title', 'body'], axis=1, inplace=True)

final_export.to_csv("Output For Tableau.csv")
